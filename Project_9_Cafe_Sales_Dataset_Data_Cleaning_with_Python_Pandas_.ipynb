# %%
import pandas as pd

# %%
df = pd.read_csv("sales.csv")

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.isna().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.describe(include="object")
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_9226047  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
df.isna().sum().sum()
# Out:
# np.int64(6826)

# %%
df = df.dropna()

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.dropna(inplace = True)
# Out:
# /tmp/ipykernel_1957/1791587065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
# 9986    TXN_2858441  Sandwich        2            4.0         8.0
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = pd.read_csv("sales.csv")
df = df.dropna()
df = df.drop_duplicates()

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
# 9986    TXN_2858441  Sandwich        2            4.0         8.0
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
pd.Series(df["Transaction ID"].unique()).str.startswith("TX").value_counts()
# Out:
# True    4550
# Name: count, dtype: int64

# %%
df["Transaction Date"].unique()
# Out:
# array(['2023-09-08', '2023-05-16', '2023-07-19', '2023-04-27',
#        '2023-06-11', '2023-10-06', '2023-10-28', '2023-11-07', 'ERROR',
#        '2023-05-03', '2023-11-15', '2023-02-24', '2023-03-25',
#        '2023-01-15', '2023-04-04', '2023-03-30', '2023-12-01',
#        '2023-06-03', '2023-04-20', '2023-04-10', '2023-11-06',
#        '2023-10-09', '2023-05-28', '2023-04-29', '2023-11-03',
#        '2023-01-08', '2023-12-05', '2023-03-19', '2023-04-19',
#        '2023-10-03', '2023-04-06', '2023-03-22', '2023-01-31',
#        '2023-12-14', '2023-07-16', '2023-06-15', '2023-12-09',
#        '2023-04-30', '2023-05-24', '2023-08-16', '2023-08-07',
#        '2023-08-20', '2023-06-10', '2023-04-15', '2023-05-27',
#        '2023-07-25', '2023-12-15', '2023-02-25', '2023-04-03',
#        '2023-12-28', 'UNKNOWN', '2023-01-10', '2023-09-23', '2023-09-14',
#        '2023-02-06', '2023-03-11', '2023-07-14', '2023-04-18',
#        '2023-12-12', '2023-01-05', '2023-09-03', '2023-06-06',
# ...

# %%
df = pd.read_csv("sales.csv")

# %%
df[df.isin(["UNKNOWN", "ERROR"]).any(axis=1)]["Payment Method"].unique()
# Out:
# array(['Credit Card', 'UNKNOWN', 'ERROR', 'Cash', nan, 'Digital Wallet'],
#       dtype=object)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
(df=='UNKNOWN').sum()
# Out:
# Transaction ID        0
# Item                344
# Quantity            171
# Price Per Unit      164
# Total Spent         165
# Payment Method      293
# Location            338
# Transaction Date    159
# dtype: int64

# %%
df=df[~df.isin(["UNKNOWN","ERROR"]).any(axis=1)]

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# 5       TXN_2602893  Smoothie        5            4.0        20.0
# 8       TXN_4717867       NaN        5            3.0        15.0
# ...             ...       ...      ...            ...         ...
# 9993    TXN_4766549  Smoothie        2            4.0         NaN
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Payment Method      object
# Location            object
# Transaction Date    object
# dtype: object

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df["Price Per Unit"] = df["Price Per Unit"].astype(float)
df["Total Spent"] = df["Total Spent"].astype(float)

# %%
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"])

# %%
df = pd.read_csv("sales.csv")

# %%
df.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Payment Method      object
# Location            object
# Transaction Date    object
# dtype: object

# %%
 df.sort_values("Transaction ID").reset_index(drop=True)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1000555       Tea        1            1.5         1.5
# 1       TXN_1001832     Salad        2            5.0        10.0
# 2       TXN_1002457    Cookie        5            1.0         5.0
# 3       TXN_1003246     Juice        2            3.0         6.0
# 4       TXN_1004184  Smoothie        1            4.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_9996968  Sandwich        1          ERROR         4.0
# 9996    TXN_9997263    Cookie        2            1.0         2.0
# 9997    TXN_9997620    Cookie        2            1.0         2.0
# 9998    TXN_9999113     Juice        4            3.0        12.0
# 9999    TXN_9999124     Juice        2            3.0         6.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  In-store       2023-10-19
# 1               Cash  Takeaway          UNKNOWN
# ...

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.to_csv("sales_cleaned.csv", index=False)

# %%
df.to_excel("sales_cleaned.xlsx", index=False)

# %%
df.to_json("sales_cleaned.json")
